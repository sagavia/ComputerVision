# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

# %%
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
print(len(flags))
# Out:
# 274

# %%
crayons = cv2.imread('crayons.jpg')
plt.imshow(crayons);

# %%
plt.imshow(cv2.cvtColor(crayons, cv2.COLOR_BGR2RGB));

# %%
crayons2 = crayons[:,:,::-1]
plt.imshow(crayons2)

# %% [markdown]
# ## 3D plots of color space

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %%
r, g, b = cv2.split(crayons)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")

pixel_colors = crayons.reshape((np.shape(crayons)[0]*np.shape(crayons)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()

# %%
hsv_crayons = cv2.cvtColor(crayons, cv2.COLOR_RGB2HSV)
h, s, v = cv2.split(hsv_crayons)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")

axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Hue")
axis.set_ylabel("Saturation")
axis.set_zlabel("Value")
plt.show()
